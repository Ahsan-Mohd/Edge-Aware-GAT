# %%
# !pip install -q MDAnalysis MDTraj torch-geometric
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 50.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 60.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.5 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
output_dir = '/content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/METHODS/MethodB/WT/'
os.makedirs(output_dir, exist_ok=True)

print(f"Working directory created at: {output_dir}")
# Out:
# Working directory created at: /content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/MethodB/WT/

# %%
import os
import numpy as np
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from MDAnalysis import Universe
from tqdm import tqdm
# Out:
# WARNING:MDAnalysis.coordinates.AMBER:netCDF4 is not available. Writing AMBER ncdf files will be slow.

# %%
import torch

data_file = os.path.join(output_dir, 'trajectory_graphs_phi_psi_rmsf_WT_rep1.pt')
data = torch.load(data_file, weights_only=False)

print(f"Loaded {len(data)} graph frames.")
print("Node feature shape:", data[0].x.shape)
print("Edge feature shape:", data[0].edge_attr.shape)
# Out:
# Loaded 4000 graph frames.
# Node feature shape: torch.Size([198, 6])
# Edge feature shape: torch.Size([3348, 3])

# %%
#Method B is GAT-EI
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import softmax


class EdgeGATConv_MethodB(MessagePassing):
    def __init__(self, in_channels, out_channels, edge_dim=3, heads=1, concat=True, dropout=0.0, bias=True):
        super().__init__(aggr='add', node_dim=0)

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.heads = heads
        self.concat = concat
        self.dropout = dropout

        self.lin = nn.Linear(in_channels, heads * out_channels, bias=False)

        # Edge projection to same shape as node message
        self.edge_lin = nn.Linear(edge_dim, heads * out_channels, bias=False)

        # Attention still uses [x_i || x_j || edge_attr]
        self.att = nn.Parameter(torch.empty(heads, 3 * out_channels))
        self.leaky_relu = nn.LeakyReLU(0.2)

        if bias:
            self.bias = nn.Parameter(torch.Tensor(heads * out_channels if concat else out_channels))
        else:
            self.register_parameter('bias', None)

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.xavier_uniform_(self.lin.weight)
        nn.init.xavier_uniform_(self.edge_lin.weight)
        nn.init.xavier_uniform_(self.att)
        if self.bias is not None:
            nn.init.zeros_(self.bias)

    def forward(self, x, edge_index, edge_attr):
        x = self.lin(x)                          # [N, H*C]
        edge_attr = self.edge_lin(edge_attr)     # [E, H*C]
        return self.propagate(edge_index=edge_index, x=x, edge_attr=edge_attr)

    def message(self, x_i, x_j, edge_attr, index):
        x_i = x_i.view(-1, self.heads, self.out_channels)
        x_j = x_j.view(-1, self.heads, self.out_channels)
        edge_attr = edge_attr.view(-1, self.heads, self.out_channels)

        # Attention score: edge-aware
        cat = torch.cat([x_i, x_j, edge_attr], dim=-1)
        alpha = torch.einsum("ehc,hc->eh", cat, self.att)
        alpha = self.leaky_relu(alpha)
        alpha = softmax(alpha, index)
        alpha = F.dropout(alpha, p=self.dropout, training=self.training)

        # Method B: edge-aware message content
        msg = x_j + edge_attr

        return msg * alpha.unsqueeze(-1)

    def update(self, aggr_out):
        if self.concat:
            aggr_out = aggr_out.view(-1, self.heads * self.out_channels)
        else:
            aggr_out = aggr_out.mean(dim=1)

        if self.bias is not None:
            aggr_out += self.bias

        return aggr_out

# %%
class EdgeGATDynamics(nn.Module):
    def __init__(self, in_features=6, hidden_dim=128, out_features=3, heads=4):
        super().__init__()
        self.gat1 = EdgeGATConv_MethodB(in_features, hidden_dim, edge_dim=3, heads=heads, concat=True)
        self.gat2 = EdgeGATConv_MethodB(hidden_dim * heads, hidden_dim, edge_dim=3, heads=heads, concat=True)
        self.gat3 = EdgeGATConv_MethodB(hidden_dim * heads, hidden_dim, edge_dim=3, heads=heads, concat=True)
        self.gat4 = EdgeGATConv_MethodB(hidden_dim * heads, hidden_dim, edge_dim=3, heads=1, concat=False)
        self.fc = nn.Linear(hidden_dim, out_features)
        self.bias = nn.Parameter(torch.ones(1))

    def forward(self, x, edge_index, edge_attr):
        x = self.gat1(x, edge_index, edge_attr)
        x = F.relu(x)
        x = self.gat2(x, edge_index, edge_attr)
        x = F.relu(x)
        x = self.gat3(x, edge_index, edge_attr)
        x = F.relu(x)
        x = self.gat4(x, edge_index, edge_attr)
        out = self.fc(x)
        return out * self.bias

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
from torch.optim import Adam

# ====== Load your data ======
data_file = os.path.join(output_dir, 'trajectory_graphs_phi_psi_rmsf_WT_rep1.pt')
data = torch.load(data_file, weights_only=False)

print(f"Loaded {len(data)} graph frames.")
print("Node feature shape:", data[0].x.shape)
print("Edge feature shape:", data[0].edge_attr.shape)

data_list = [d.to('cuda' if torch.cuda.is_available() else 'cpu') for d in data]

# ====== Model, optimizer, loss ======
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = EdgeGATDynamics(in_features=6, hidden_dim=128, out_features=3, heads=4).to(device)
optimizer = Adam(model.parameters(), lr=5e-4)  # 🔽 Lower LR for stability
loss_fn = nn.MSELoss()

# ====== Training settings ======
epochs = 100
patience = 20
best_loss = float('inf')
counter = 0

model_save_path = os.path.join(output_dir, "edgegat_dynamics_best_WT_rep1.pt")

# ====== Training loop ======
for epoch in range(1, epochs + 1):
    model.train()
    total_loss = 0.0

    for i in range(len(data_list) - 1):
        data_curr = data_list[i]
        data_next = data_list[i + 1]

        optimizer.zero_grad()
        pred = model(data_curr.x, data_curr.edge_index, data_curr.edge_attr)
        target = data_next.x[:, :3]  # ⬅️ Only coordinate portion
        loss = loss_fn(pred, target)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / (len(data_list) - 1)
    print(f"Epoch {epoch:3d} | Avg Loss: {avg_loss:.6f}")

    # Save best model
    if avg_loss < best_loss:
        best_loss = avg_loss
        counter = 0
        torch.save(model.state_dict(), model_save_path)
        print(f"✅ Best model saved! Loss: {best_loss:.6f}")
    else:
        counter += 1
        if counter >= patience:
            print(f"⏹️ Early stopping at epoch {epoch} (no improvement for {patience} epochs)")
            break
# Out:
# Loaded 4000 graph frames.
# Node feature shape: torch.Size([198, 6])
# Edge feature shape: torch.Size([3348, 3])
# Epoch   1 | Avg Loss: 4.992060
# ✅ Best model saved! Loss: 4.992060
# Epoch   2 | Avg Loss: 0.945792
# ✅ Best model saved! Loss: 0.945792
# Epoch   3 | Avg Loss: 0.699217
# ✅ Best model saved! Loss: 0.699217
# Epoch   4 | Avg Loss: 0.503972
# ✅ Best model saved! Loss: 0.503972
# Epoch   5 | Avg Loss: 0.393998
# ✅ Best model saved! Loss: 0.393998
# Epoch   6 | Avg Loss: 0.331391
# ✅ Best model saved! Loss: 0.331391
# Epoch   7 | Avg Loss: 0.298451
# ✅ Best model saved! Loss: 0.298451
# Epoch   8 | Avg Loss: 0.274984
# ✅ Best model saved! Loss: 0.274984
# Epoch   9 | Avg Loss: 0.258150
# ✅ Best model saved! Loss: 0.258150
# Epoch  10 | Avg Loss: 0.247323
# ✅ Best model saved! Loss: 0.247323
# Epoch  11 | Avg Loss: 0.237144
# ✅ Best model saved! Loss: 0.237144
# Epoch  12 | Avg Loss: 0.229619
# ✅ Best model saved! Loss: 0.229619
# Epoch  13 | Avg Loss: 0.223820
# ✅ Best model saved! Loss: 0.223820
# Epoch  14 | Avg Loss: 0.218797
# ✅ Best model saved! Loss: 0.218797
# Epoch  15 | Avg Loss: 0.214050
# ✅ Best model saved! Loss: 0.214050
# Epoch  16 | Avg Loss: 0.210315
# ✅ Best model saved! Loss: 0.210315
# Epoch  17 | Avg Loss: 0.206615
# ✅ Best model saved! Loss: 0.206615
# Epoch  18 | Avg Loss: 0.204196
# ✅ Best model saved! Loss: 0.204196
# Epoch  19 | Avg Loss: 0.201357
# ✅ Best model saved! Loss: 0.201357
# Epoch  20 | Avg Loss: 0.198938
# ✅ Best model saved! Loss: 0.198938
# Epoch  21 | Avg Loss: 0.197230
# ✅ Best model saved! Loss: 0.197230
# Epoch  22 | Avg Loss: 0.194595
# ✅ Best model saved! Loss: 0.194595
# Epoch  23 | Avg Loss: 0.193191
# ✅ Best model saved! Loss: 0.193191
# Epoch  24 | Avg Loss: 0.191415
# ✅ Best model saved! Loss: 0.191415
# Epoch  25 | Avg Loss: 0.190337
# ✅ Best model saved! Loss: 0.190337
# Epoch  26 | Avg Loss: 0.188386
# ✅ Best model saved! Loss: 0.188386
# Epoch  27 | Avg Loss: 0.186960
# ✅ Best model saved! Loss: 0.186960
# Epoch  28 | Avg Loss: 0.185618
# ✅ Best model saved! Loss: 0.185618
# Epoch  29 | Avg Loss: 0.184770
# ✅ Best model saved! Loss: 0.184770
# Epoch  30 | Avg Loss: 0.183530
# ✅ Best model saved! Loss: 0.183530
# Epoch  31 | Avg Loss: 0.182777
# ✅ Best model saved! Loss: 0.182777
# Epoch  32 | Avg Loss: 0.181530
# ✅ Best model saved! Loss: 0.181530
# Epoch  33 | Avg Loss: 0.181180
# ✅ Best model saved! Loss: 0.181180
# Epoch  34 | Avg Loss: 0.180169
# ✅ Best model saved! Loss: 0.180169
# Epoch  35 | Avg Loss: 0.178650
# ✅ Best model saved! Loss: 0.178650
# Epoch  36 | Avg Loss: 0.179141
# Epoch  37 | Avg Loss: 0.177639
# ✅ Best model saved! Loss: 0.177639
# Epoch  38 | Avg Loss: 0.176716
# ✅ Best model saved! Loss: 0.176716
# Epoch  39 | Avg Loss: 0.176585
# ✅ Best model saved! Loss: 0.176585
# Epoch  40 | Avg Loss: 0.175548
# ✅ Best model saved! Loss: 0.175548
# Epoch  41 | Avg Loss: 0.174978
# ✅ Best model saved! Loss: 0.174978
# Epoch  42 | Avg Loss: 0.173972
# ✅ Best model saved! Loss: 0.173972
# Epoch  43 | Avg Loss: 0.173694
# ✅ Best model saved! Loss: 0.173694
# Epoch  44 | Avg Loss: 0.173026
# ✅ Best model saved! Loss: 0.173026
# Epoch  45 | Avg Loss: 0.171905
# ✅ Best model saved! Loss: 0.171905
# Epoch  46 | Avg Loss: 0.171774
# ✅ Best model saved! Loss: 0.171774
# Epoch  47 | Avg Loss: 0.171538
# ✅ Best model saved! Loss: 0.171538
# Epoch  48 | Avg Loss: 0.171058
# ✅ Best model saved! Loss: 0.171058
# Epoch  49 | Avg Loss: 0.170188
# ✅ Best model saved! Loss: 0.170188
# Epoch  50 | Avg Loss: 0.169986
# ✅ Best model saved! Loss: 0.169986
# Epoch  51 | Avg Loss: 0.169262
# ✅ Best model saved! Loss: 0.169262
# Epoch  52 | Avg Loss: 0.168780
# ✅ Best model saved! Loss: 0.168780
# Epoch  53 | Avg Loss: 0.168387
# ✅ Best model saved! Loss: 0.168387
# Epoch  54 | Avg Loss: 0.167751
# ✅ Best model saved! Loss: 0.167751
# Epoch  55 | Avg Loss: 0.167381
# ✅ Best model saved! Loss: 0.167381
# Epoch  56 | Avg Loss: 0.166781
# ✅ Best model saved! Loss: 0.166781
# Epoch  57 | Avg Loss: 0.166560
# ✅ Best model saved! Loss: 0.166560
# Epoch  58 | Avg Loss: 0.166298
# ✅ Best model saved! Loss: 0.166298
# Epoch  59 | Avg Loss: 0.166066
# ✅ Best model saved! Loss: 0.166066
# Epoch  60 | Avg Loss: 0.165444
# ✅ Best model saved! Loss: 0.165444
# Epoch  61 | Avg Loss: 0.165205
# ✅ Best model saved! Loss: 0.165205
# Epoch  62 | Avg Loss: 0.164968
# ✅ Best model saved! Loss: 0.164968
# Epoch  63 | Avg Loss: 0.164542
# ✅ Best model saved! Loss: 0.164542
# Epoch  64 | Avg Loss: 0.164148
# ✅ Best model saved! Loss: 0.164148
# Epoch  65 | Avg Loss: 0.163969
# ✅ Best model saved! Loss: 0.163969
# Epoch  66 | Avg Loss: 0.163293
# ✅ Best model saved! Loss: 0.163293
# Epoch  67 | Avg Loss: 0.163005
# ✅ Best model saved! Loss: 0.163005
# Epoch  68 | Avg Loss: 0.163142
# Epoch  69 | Avg Loss: 0.162488
# ✅ Best model saved! Loss: 0.162488
# Epoch  70 | Avg Loss: 0.162203
# ✅ Best model saved! Loss: 0.162203
# Epoch  71 | Avg Loss: 0.161574
# ✅ Best model saved! Loss: 0.161574
# Epoch  72 | Avg Loss: 0.161350
# ✅ Best model saved! Loss: 0.161350
# Epoch  73 | Avg Loss: 0.161422
# Epoch  74 | Avg Loss: 0.160484
# ✅ Best model saved! Loss: 0.160484
# Epoch  75 | Avg Loss: 0.160723
# Epoch  76 | Avg Loss: 0.160233
# ✅ Best model saved! Loss: 0.160233
# Epoch  77 | Avg Loss: 0.160071
# ✅ Best model saved! Loss: 0.160071
# Epoch  78 | Avg Loss: 0.159642
# ✅ Best model saved! Loss: 0.159642
# Epoch  79 | Avg Loss: 0.159513
# ✅ Best model saved! Loss: 0.159513
# Epoch  80 | Avg Loss: 0.158789
# ✅ Best model saved! Loss: 0.158789
# Epoch  81 | Avg Loss: 0.158507
# ✅ Best model saved! Loss: 0.158507
# Epoch  82 | Avg Loss: 0.158384
# ✅ Best model saved! Loss: 0.158384
# Epoch  83 | Avg Loss: 0.158839
# Epoch  84 | Avg Loss: 0.158276
# ✅ Best model saved! Loss: 0.158276
# Epoch  85 | Avg Loss: 0.157902
# ✅ Best model saved! Loss: 0.157902
# Epoch  86 | Avg Loss: 0.157253
# ✅ Best model saved! Loss: 0.157253
# Epoch  87 | Avg Loss: 0.157600
# Epoch  88 | Avg Loss: 0.156813
# ✅ Best model saved! Loss: 0.156813
# Epoch  89 | Avg Loss: 0.156723
# ✅ Best model saved! Loss: 0.156723
# Epoch  90 | Avg Loss: 0.156996
# Epoch  91 | Avg Loss: 0.156088
# ✅ Best model saved! Loss: 0.156088
# Epoch  92 | Avg Loss: 0.155916
# ✅ Best model saved! Loss: 0.155916
# Epoch  93 | Avg Loss: 0.156438
# Epoch  94 | Avg Loss: 0.155369
# ✅ Best model saved! Loss: 0.155369
# Epoch  95 | Avg Loss: 0.155089
# ✅ Best model saved! Loss: 0.155089
# Epoch  96 | Avg Loss: 0.155146
# Epoch  97 | Avg Loss: 0.155275
# Epoch  98 | Avg Loss: 0.154984
# ✅ Best model saved! Loss: 0.154984
# Epoch  99 | Avg Loss: 0.154096
# ✅ Best model saved! Loss: 0.154096
# Epoch 100 | Avg Loss: 0.154112

# %%
model_path = os.path.join(output_dir, "edgegat_dynamics_best_WT_rep1.pt")
data_file = os.path.join(output_dir, 'trajectory_graphs_phi_psi_rmsf_WT_rep1.pt')

# %%
import os
import torch

# Set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = EdgeGATDynamics(in_features=6, hidden_dim=128, out_features=3, heads=4).to(device)

# Load the data
data_list_cpu = torch.load(data_file, weights_only=False)
data_list = [d.to(device) for d in data_list_cpu] # Move data to the correct device

model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

print("✅ Model loaded successfully on device:", device)
# Out:
# ✅ Model loaded successfully on device: cuda

# %%
def kabsch_align(P, Q):
    """
    Aligns P (pred) to Q (true) using Kabsch algorithm.
    Returns: P_aligned [N, 3]
    """
    # Subtract centroids
    P_mean = P.mean(dim=0, keepdim=True)
    Q_mean = Q.mean(dim=0, keepdim=True)

    P_centered = P - P_mean
    Q_centered = Q - Q_mean

    # Compute covariance matrix
    C = torch.matmul(P_centered.T, Q_centered)

    # SVD
    V, S, Wt = torch.linalg.svd(C)
    d = torch.det(torch.matmul(V, Wt))
    D = torch.diag(torch.tensor([1., 1., d], device=P.device))

    # Rotation
    U = torch.matmul(torch.matmul(V, D), Wt)

    # Rotate and re-center
    P_rot = torch.matmul(P_centered, U)

    return P_rot + Q_mean

# %%
def compute_kabsch_rmsd(P, Q):
    P_aligned = kabsch_align(P, Q)
    return torch.sqrt(((P_aligned - Q) ** 2).sum(dim=1).mean()).item()

# %%
model.eval()
kabsch_rmsds = []

with torch.no_grad():
    for i in range(len(data_list) - 1):
        d0 = data_list[i]
        d1 = data_list[i + 1]

        pred = model(d0.x, d0.edge_index, d0.edge_attr)
        true = d1.x[:, :3]

        rmsd_kabsch = compute_kabsch_rmsd(pred, true)
        kabsch_rmsds.append(rmsd_kabsch)

print(f"\n✅ Kabsch-aligned RMSD: {np.mean(kabsch_rmsds):.3f} Å")
# Out:
# ✅ Kabsch-aligned RMSD: 0.851 Å

# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

kabsch_rmsds = []

model.eval()
with torch.no_grad():
    for i in tqdm(range(len(data_list) - 1)):
        d0 = data_list[i]
        d1 = data_list[i + 1]

        pred = model(d0.x, d0.edge_index, d0.edge_attr)
        true = d1.x[:, :3]

        rmsd_kabsch = compute_kabsch_rmsd(pred, true)
        kabsch_rmsds.append(rmsd_kabsch)

# Convert to numpy
kabsch_rmsds = np.array(kabsch_rmsds)
frame_indices = np.arange(len(kabsch_rmsds))

# === FIGURE CREATION ===
fig, ax = plt.subplots(figsize=(11, 4))

ax.plot(frame_indices, kabsch_rmsds, marker='o', linewidth=1)
ax.set_title("Kabsch-Aligned RMSD Over Trajectory")
ax.set_xlabel("Frame Index (i → i+1)")
ax.set_ylabel("RMSD (Å)")
ax.grid(True)

mean_val = kabsch_rmsds.mean()

# === ADD MEAN RMSD TEXT ON PLOT ===
ax.text(
    0.02, 0.95,
    f"Mean RMSD = {mean_val:.3f} Å",
    transform=ax.transAxes,
    fontsize=12,
    verticalalignment='top',
    bbox=dict(facecolor="white", alpha=0.7, edgecolor="black")
)

fig.tight_layout()

# === SAVE PNG ===
out_file = "/content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/METHODS/MethodB/WT/kabsch_rmsd_true_pred_rep1.png"
fig.savefig(out_file, dpi=300, transparent=False)

print(f"📁 Saved RMSD plot to: {out_file}")
print(f"Mean RMSD = {mean_val:.3f} Å")

plt.show()
plt.close(fig)
# Out:
# 100%|██████████| 3999/3999 [00:19<00:00, 207.04it/s]
# 📁 Saved RMSD plot to: /content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/MethodB/WT/kabsch_rmsd_true_pred_rep3.png
# Mean RMSD = 0.851 Å

# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# Store traditional RMSD for both predicted and true trajectories
pred_rmsds = []
true_rmsds = []

model.eval()
with torch.no_grad():
    # First frame as reference
    ref_frame = data_list[0].x[:, :3]

    for i in tqdm(range(len(data_list) - 1)):
        d0 = data_list[i]
        d1 = data_list[i + 1]

        pred = model(d0.x, d0.edge_index, d0.edge_attr)
        true = d1.x[:, :3]

        pred_rmsds.append(compute_kabsch_rmsd(pred, ref_frame))
        true_rmsds.append(compute_kabsch_rmsd(true, ref_frame))

# Convert to numpy
pred_rmsds = np.array(pred_rmsds)
true_rmsds = np.array(true_rmsds)
frame_indices = np.arange(len(pred_rmsds))

mean_true = true_rmsds.mean()
mean_pred = pred_rmsds.mean()

# === FIGURE CREATION (SAFE) ===
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(frame_indices, true_rmsds, label="True Dynamics", marker='o', linewidth=1)
ax.plot(frame_indices, pred_rmsds, label="Predicted Dynamics", marker='x', linewidth=1, linestyle='dashed')

ax.set_title("Traditional RMSD: Predicted vs. True Dynamics")
ax.set_xlabel("Frame Index (relative to first)")
ax.set_ylabel("RMSD (Å)")
ax.grid(True)
ax.legend()

# === ADD MEAN VALUES TEXT TO PLOT ===
text_str = (
    f"Mean True RMSD: {mean_true:.3f} Å\n"
    f"Mean Pred RMSD: {mean_pred:.3f} Å"
)

ax.text(
    0.02, 0.95, text_str,
    transform=ax.transAxes,
    fontsize=12,
    verticalalignment='top',
    bbox=dict(facecolor="white", alpha=0.75, edgecolor="black")
)

fig.tight_layout()

# === SAVE BEFORE SHOW ===
out_file = "/content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/METHODS/MethodB/WT/rmsd_firstframe_true_pred_rep1.png"
fig.savefig(out_file, dpi=300, transparent=False)

print(f"📁 Saved RMSD plot to: {out_file}")

# Show the figure (optional)
plt.show()
plt.close(fig)

# === PRINT STATS IN TERMINAL ===
print(f"✅ Mean True Dynamics RMSD: {mean_true:.3f} Å")
print(f"Min: {true_rmsds.min():.3f} Å | Max: {true_rmsds.max():.3f} Å")

print(f"✅ Mean Predicted Dynamics RMSD: {mean_pred:.3f} Å")
print(f"Min: {pred_rmsds.min():.3f} Å | Max: {pred_rmsds.max():.3f} Å")
# Out:
# 100%|██████████| 3999/3999 [00:22<00:00, 176.99it/s]
# 📁 Saved RMSD plot to: /content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/MethodB/WT/rmsd_firstframe_true_pred_rep3.png
# ✅ Mean True Dynamics RMSD: 1.215 Å
# Min: 0.696 Å | Max: 1.746 Å
# ✅ Mean Predicted Dynamics RMSD: 1.131 Å
# Min: 0.781 Å | Max: 1.358 Å
