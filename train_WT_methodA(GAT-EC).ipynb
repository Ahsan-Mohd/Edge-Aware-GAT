# %%
# !pip install -q MDAnalysis MDTraj torch-geometric
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 50.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 142.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 130.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.3 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
output_dir = '/content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/METHODS/MethodA/WT/'
os.makedirs(output_dir, exist_ok=True)

print(f"Working directory created at: {output_dir}")
# Out:
# Working directory created at: /content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/MethodA/WT/

# %%
import os
import numpy as np
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from MDAnalysis import Universe
from tqdm import tqdm
# Out:
# WARNING:MDAnalysis.coordinates.AMBER:netCDF4 is not available. Writing AMBER ncdf files will be slow.

# %%
import torch

data_file = os.path.join(output_dir, 'trajectory_graphs_phi_psi_rmsf_WT_rep1.pt')
data = torch.load(data_file, weights_only=False)

print(f"Loaded {len(data)} graph frames.")
print("Node feature shape:", data[0].x.shape)
print("Edge feature shape:", data[0].edge_attr.shape)
# Out:
# Loaded 4000 graph frames.
# Node feature shape: torch.Size([198, 6])
# Edge feature shape: torch.Size([3348, 3])

# %%
#Method A is GAT-EC
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import softmax

class EdgeGATConv_MethodA(MessagePassing):
    def __init__(self, in_channels, out_channels, edge_dim=3, heads=1, concat=True, dropout=0.0, bias=True):
        super().__init__(aggr='add', node_dim=0)  # Ensures node-wise aggregation
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.heads = heads
        self.concat = concat
        self.dropout = dropout

        # Linear transformation for node features
        self.lin = nn.Linear(in_channels, heads * out_channels, bias=False)

        # Linear transformation for edge features — now 3D input
        self.edge_lin = nn.Linear(edge_dim, heads * out_channels, bias=False)

        # Attention parameters: one set per head
        self.att = nn.Parameter(torch.empty(heads, 3 * out_channels))  # [H, 3C]
        self.leaky_relu = nn.LeakyReLU(0.2)

        if bias:
            self.bias = nn.Parameter(torch.Tensor(heads * out_channels if concat else out_channels))
        else:
            self.register_parameter('bias', None)

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.xavier_uniform_(self.lin.weight)
        nn.init.xavier_uniform_(self.edge_lin.weight)
        nn.init.xavier_uniform_(self.att)
        if self.bias is not None:
            nn.init.zeros_(self.bias)

    def forward(self, x, edge_index, edge_attr):
        # x: [N, in_channels]
        # edge_attr: [E, 3]
        x = self.lin(x)  # [N, H * C]
        edge_attr = self.edge_lin(edge_attr)  # [E, H * C]
        return self.propagate(edge_index=edge_index, x=x, edge_attr=edge_attr)

    def message(self, x_i, x_j, edge_attr, index):
        # Reshape for multi-head attention
        x_i = x_i.view(-1, self.heads, self.out_channels)         # [E, H, C]
        x_j = x_j.view(-1, self.heads, self.out_channels)
        edge_attr = edge_attr.view(-1, self.heads, self.out_channels)

        # Concatenate: [x_i || x_j || edge_attr] → [E, H, 3C]
        cat = torch.cat([x_i, x_j, edge_attr], dim=-1)

        # Compute attention scores
        alpha = torch.einsum("ehc,hc->eh", cat, self.att)  # [E, H]
        alpha = self.leaky_relu(alpha)
        alpha = softmax(alpha, index)  # Normalize across incoming edges
        alpha = F.dropout(alpha, p=self.dropout, training=self.training)

        return x_j * alpha.unsqueeze(-1)  # Apply attention to messages

    def update(self, aggr_out):
        # Combine attention heads
        if self.concat:
            aggr_out = aggr_out.view(-1, self.heads * self.out_channels)  # [N, H*C]
        else:
            aggr_out = aggr_out.mean(dim=1)  # [N, C]

        if self.bias is not None:
            aggr_out += self.bias

        return aggr_out

# %%
class EdgeGATDynamics(nn.Module):
    def __init__(self, in_features=6, hidden_dim=128, out_features=3, heads=4):
        super().__init__()
        self.gat1 = EdgeGATConv_MethodA(in_features, hidden_dim, edge_dim=3, heads=heads, concat=True)
        self.gat2 = EdgeGATConv_MethodA(hidden_dim * heads, hidden_dim, edge_dim=3, heads=heads, concat=True)
        self.gat3 = EdgeGATConv_MethodA(hidden_dim * heads, hidden_dim, edge_dim=3, heads=heads, concat=True)
        self.gat4 = EdgeGATConv_MethodA(hidden_dim * heads, hidden_dim, edge_dim=3, heads=1, concat=False)
        self.fc = nn.Linear(hidden_dim, out_features)
        self.bias = nn.Parameter(torch.ones(1))

    def forward(self, x, edge_index, edge_attr):
        x = self.gat1(x, edge_index, edge_attr)
        x = F.relu(x)
        x = self.gat2(x, edge_index, edge_attr)
        x = F.relu(x)
        x = self.gat3(x, edge_index, edge_attr)
        x = F.relu(x)
        x = self.gat4(x, edge_index, edge_attr)
        out = self.fc(x)
        return out * self.bias

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
from torch.optim import Adam

# ====== Load your data ======
data_file = os.path.join(output_dir, 'trajectory_graphs_phi_psi_rmsf_WT_rep1.pt')
data = torch.load(data_file, weights_only=False)

print(f"Loaded {len(data)} graph frames.")
print("Node feature shape:", data[0].x.shape)
print("Edge feature shape:", data[0].edge_attr.shape)

data_list = [d.to('cuda' if torch.cuda.is_available() else 'cpu') for d in data]

# ====== Model, optimizer, loss ======
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = EdgeGATDynamics(in_features=6, hidden_dim=128, out_features=3, heads=4).to(device)
optimizer = Adam(model.parameters(), lr=5e-4)  # 🔽 Lower LR for stability
loss_fn = nn.MSELoss()

# ====== Training settings ======
epochs = 100
patience = 20
best_loss = float('inf')
counter = 0

model_save_path = os.path.join(output_dir, "edgegat_dynamics_best_WT_rep1.pt")

# ====== Training loop ======
for epoch in range(1, epochs + 1):
    model.train()
    total_loss = 0.0

    for i in range(len(data_list) - 1):
        data_curr = data_list[i]
        data_next = data_list[i + 1]

        optimizer.zero_grad()
        pred = model(data_curr.x, data_curr.edge_index, data_curr.edge_attr)
        target = data_next.x[:, :3]  # ⬅️ Only coordinate portion
        loss = loss_fn(pred, target)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / (len(data_list) - 1)
    print(f"Epoch {epoch:3d} | Avg Loss: {avg_loss:.6f}")

    # Save best model
    if avg_loss < best_loss:
        best_loss = avg_loss
        counter = 0
        torch.save(model.state_dict(), model_save_path)
        print(f"✅ Best model saved! Loss: {best_loss:.6f}")
    else:
        counter += 1
        if counter >= patience:
            print(f"⏹️ Early stopping at epoch {epoch} (no improvement for {patience} epochs)")
            break
# Out:
# Loaded 4000 graph frames.
# Node feature shape: torch.Size([198, 6])
# Edge feature shape: torch.Size([3348, 3])
# Epoch   1 | Avg Loss: 5.757834
# ✅ Best model saved! Loss: 5.757834
# Epoch   2 | Avg Loss: 0.897755
# ✅ Best model saved! Loss: 0.897755
# Epoch   3 | Avg Loss: 0.619601
# ✅ Best model saved! Loss: 0.619601
# Epoch   4 | Avg Loss: 0.467668
# ✅ Best model saved! Loss: 0.467668
# Epoch   5 | Avg Loss: 0.376318
# ✅ Best model saved! Loss: 0.376318
# Epoch   6 | Avg Loss: 0.329366
# ✅ Best model saved! Loss: 0.329366
# Epoch   7 | Avg Loss: 0.297515
# ✅ Best model saved! Loss: 0.297515
# Epoch   8 | Avg Loss: 0.274614
# ✅ Best model saved! Loss: 0.274614
# Epoch   9 | Avg Loss: 0.260642
# ✅ Best model saved! Loss: 0.260642
# Epoch  10 | Avg Loss: 0.249189
# ✅ Best model saved! Loss: 0.249189
# Epoch  11 | Avg Loss: 0.240351
# ✅ Best model saved! Loss: 0.240351
# Epoch  12 | Avg Loss: 0.233678
# ✅ Best model saved! Loss: 0.233678
# Epoch  13 | Avg Loss: 0.226263
# ✅ Best model saved! Loss: 0.226263
# Epoch  14 | Avg Loss: 0.223003
# ✅ Best model saved! Loss: 0.223003
# Epoch  15 | Avg Loss: 0.218401
# ✅ Best model saved! Loss: 0.218401
# Epoch  16 | Avg Loss: 0.215410
# ✅ Best model saved! Loss: 0.215410
# Epoch  17 | Avg Loss: 0.211452
# ✅ Best model saved! Loss: 0.211452
# Epoch  18 | Avg Loss: 0.209327
# ✅ Best model saved! Loss: 0.209327
# Epoch  19 | Avg Loss: 0.206990
# ✅ Best model saved! Loss: 0.206990
# Epoch  20 | Avg Loss: 0.204531
# ✅ Best model saved! Loss: 0.204531
# Epoch  21 | Avg Loss: 0.201859
# ✅ Best model saved! Loss: 0.201859
# Epoch  22 | Avg Loss: 0.201056
# ✅ Best model saved! Loss: 0.201056
# Epoch  23 | Avg Loss: 0.198685
# ✅ Best model saved! Loss: 0.198685
# Epoch  24 | Avg Loss: 0.197292
# ✅ Best model saved! Loss: 0.197292
# Epoch  25 | Avg Loss: 0.195886
# ✅ Best model saved! Loss: 0.195886
# Epoch  26 | Avg Loss: 0.194451
# ✅ Best model saved! Loss: 0.194451
# Epoch  27 | Avg Loss: 0.192493
# ✅ Best model saved! Loss: 0.192493
# Epoch  28 | Avg Loss: 0.190532
# ✅ Best model saved! Loss: 0.190532
# Epoch  29 | Avg Loss: 0.190526
# ✅ Best model saved! Loss: 0.190526
# Epoch  30 | Avg Loss: 0.189634
# ✅ Best model saved! Loss: 0.189634
# Epoch  31 | Avg Loss: 0.187984
# ✅ Best model saved! Loss: 0.187984
# Epoch  32 | Avg Loss: 0.187114
# ✅ Best model saved! Loss: 0.187114
# Epoch  33 | Avg Loss: 0.185724
# ✅ Best model saved! Loss: 0.185724
# Epoch  34 | Avg Loss: 0.185544
# ✅ Best model saved! Loss: 0.185544
# Epoch  35 | Avg Loss: 0.184267
# ✅ Best model saved! Loss: 0.184267
# Epoch  36 | Avg Loss: 0.182980
# ✅ Best model saved! Loss: 0.182980
# Epoch  37 | Avg Loss: 0.182346
# ✅ Best model saved! Loss: 0.182346
# Epoch  38 | Avg Loss: 0.181875
# ✅ Best model saved! Loss: 0.181875
# Epoch  39 | Avg Loss: 0.181455
# ✅ Best model saved! Loss: 0.181455
# Epoch  40 | Avg Loss: 0.180371
# ✅ Best model saved! Loss: 0.180371
# Epoch  41 | Avg Loss: 0.180240
# ✅ Best model saved! Loss: 0.180240
# Epoch  42 | Avg Loss: 0.178865
# ✅ Best model saved! Loss: 0.178865
# Epoch  43 | Avg Loss: 0.178572
# ✅ Best model saved! Loss: 0.178572
# Epoch  44 | Avg Loss: 0.177941
# ✅ Best model saved! Loss: 0.177941
# Epoch  45 | Avg Loss: 0.177571
# ✅ Best model saved! Loss: 0.177571
# Epoch  46 | Avg Loss: 0.177138
# ✅ Best model saved! Loss: 0.177138
# Epoch  47 | Avg Loss: 0.177613
# Epoch  48 | Avg Loss: 0.175547
# ✅ Best model saved! Loss: 0.175547
# Epoch  49 | Avg Loss: 0.174570
# ✅ Best model saved! Loss: 0.174570
# Epoch  50 | Avg Loss: 0.175010
# Epoch  51 | Avg Loss: 0.174586
# Epoch  52 | Avg Loss: 0.173206
# ✅ Best model saved! Loss: 0.173206
# Epoch  53 | Avg Loss: 0.173114
# ✅ Best model saved! Loss: 0.173114
# Epoch  54 | Avg Loss: 0.173635
# Epoch  55 | Avg Loss: 0.172727
# ✅ Best model saved! Loss: 0.172727
# Epoch  56 | Avg Loss: 0.171712
# ✅ Best model saved! Loss: 0.171712
# Epoch  57 | Avg Loss: 0.172342
# Epoch  58 | Avg Loss: 0.170577
# ✅ Best model saved! Loss: 0.170577
# Epoch  59 | Avg Loss: 0.171039
# Epoch  60 | Avg Loss: 0.169974
# ✅ Best model saved! Loss: 0.169974
# Epoch  61 | Avg Loss: 0.168880
# ✅ Best model saved! Loss: 0.168880
# Epoch  62 | Avg Loss: 0.170044
# Epoch  63 | Avg Loss: 0.170178
# Epoch  64 | Avg Loss: 0.169473
# Epoch  65 | Avg Loss: 0.168681
# ✅ Best model saved! Loss: 0.168681
# Epoch  66 | Avg Loss: 0.168022
# ✅ Best model saved! Loss: 0.168022
# Epoch  67 | Avg Loss: 0.168207
# Epoch  68 | Avg Loss: 0.168100
# Epoch  69 | Avg Loss: 0.166479
# ✅ Best model saved! Loss: 0.166479
# Epoch  70 | Avg Loss: 0.166095
# ✅ Best model saved! Loss: 0.166095
# Epoch  71 | Avg Loss: 0.166054
# ✅ Best model saved! Loss: 0.166054
# Epoch  72 | Avg Loss: 0.166398
# Epoch  73 | Avg Loss: 0.166128
# Epoch  74 | Avg Loss: 0.166122
# Epoch  75 | Avg Loss: 0.165474
# ✅ Best model saved! Loss: 0.165474
# Epoch  76 | Avg Loss: 0.164661
# ✅ Best model saved! Loss: 0.164661
# Epoch  77 | Avg Loss: 0.164951
# Epoch  78 | Avg Loss: 0.164529
# ✅ Best model saved! Loss: 0.164529
# Epoch  79 | Avg Loss: 0.164294
# ✅ Best model saved! Loss: 0.164294
# Epoch  80 | Avg Loss: 0.163777
# ✅ Best model saved! Loss: 0.163777
# Epoch  81 | Avg Loss: 0.163281
# ✅ Best model saved! Loss: 0.163281
# Epoch  82 | Avg Loss: 0.163611
# Epoch  83 | Avg Loss: 0.163209
# ✅ Best model saved! Loss: 0.163209
# Epoch  84 | Avg Loss: 0.162326
# ✅ Best model saved! Loss: 0.162326
# Epoch  85 | Avg Loss: 0.162084
# ✅ Best model saved! Loss: 0.162084
# Epoch  86 | Avg Loss: 0.161846
# ✅ Best model saved! Loss: 0.161846
# Epoch  87 | Avg Loss: 0.161797
# ✅ Best model saved! Loss: 0.161797
# Epoch  88 | Avg Loss: 0.162583
# Epoch  89 | Avg Loss: 0.161542
# ✅ Best model saved! Loss: 0.161542
# Epoch  90 | Avg Loss: 0.161081
# ✅ Best model saved! Loss: 0.161081
# Epoch  91 | Avg Loss: 0.161865
# Epoch  92 | Avg Loss: 0.161624
# Epoch  93 | Avg Loss: 0.160433
# ✅ Best model saved! Loss: 0.160433
# Epoch  94 | Avg Loss: 0.159729
# ✅ Best model saved! Loss: 0.159729
# Epoch  95 | Avg Loss: 0.160257
# Epoch  96 | Avg Loss: 0.160159
# Epoch  97 | Avg Loss: 0.159442
# ✅ Best model saved! Loss: 0.159442
# Epoch  98 | Avg Loss: 0.159729
# Epoch  99 | Avg Loss: 0.159245
# ✅ Best model saved! Loss: 0.159245
# Epoch 100 | Avg Loss: 0.159620

# %%
model_path = os.path.join(output_dir, "edgegat_dynamics_best_WT_rep1.pt")
data_file = os.path.join(output_dir, 'trajectory_graphs_phi_psi_rmsf_WT_rep1.pt')

# %%
import os
import torch

# Set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = EdgeGATDynamics(in_features=6, hidden_dim=128, out_features=3, heads=4).to(device)

# Load the data
data_list_cpu = torch.load(data_file, weights_only=False)
data_list = [d.to(device) for d in data_list_cpu] # Move data to the correct device

model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

print("✅ Model loaded successfully on device:", device)
# Out:
# ✅ Model loaded successfully on device: cuda

# %%
def kabsch_align(P, Q):
    """
    Aligns P (pred) to Q (true) using Kabsch algorithm.
    Returns: P_aligned [N, 3]
    """
    # Subtract centroids
    P_mean = P.mean(dim=0, keepdim=True)
    Q_mean = Q.mean(dim=0, keepdim=True)

    P_centered = P - P_mean
    Q_centered = Q - Q_mean

    # Compute covariance matrix
    C = torch.matmul(P_centered.T, Q_centered)

    # SVD
    V, S, Wt = torch.linalg.svd(C)
    d = torch.det(torch.matmul(V, Wt))
    D = torch.diag(torch.tensor([1., 1., d], device=P.device))

    # Rotation
    U = torch.matmul(torch.matmul(V, D), Wt)

    # Rotate and re-center
    P_rot = torch.matmul(P_centered, U)

    return P_rot + Q_mean

# %%
def compute_kabsch_rmsd(P, Q):
    P_aligned = kabsch_align(P, Q)
    return torch.sqrt(((P_aligned - Q) ** 2).sum(dim=1).mean()).item()

# %%
model.eval()
kabsch_rmsds = []

with torch.no_grad():
    for i in range(len(data_list) - 1):
        d0 = data_list[i]
        d1 = data_list[i + 1]

        pred = model(d0.x, d0.edge_index, d0.edge_attr)
        true = d1.x[:, :3]

        rmsd_kabsch = compute_kabsch_rmsd(pred, true)
        kabsch_rmsds.append(rmsd_kabsch)

print(f"\n✅ Kabsch-aligned RMSD: {np.mean(kabsch_rmsds):.3f} Å")
# Out:
# ✅ Kabsch-aligned RMSD: 0.867 Å

# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

kabsch_rmsds = []

model.eval()
with torch.no_grad():
    for i in tqdm(range(len(data_list) - 1)):
        d0 = data_list[i]
        d1 = data_list[i + 1]

        pred = model(d0.x, d0.edge_index, d0.edge_attr)
        true = d1.x[:, :3]

        rmsd_kabsch = compute_kabsch_rmsd(pred, true)
        kabsch_rmsds.append(rmsd_kabsch)

# Convert to numpy
kabsch_rmsds = np.array(kabsch_rmsds)
frame_indices = np.arange(len(kabsch_rmsds))

# === FIGURE CREATION ===
fig, ax = plt.subplots(figsize=(11, 4))

ax.plot(frame_indices, kabsch_rmsds, marker='o', linewidth=1)
ax.set_title("Kabsch-Aligned RMSD Over Trajectory")
ax.set_xlabel("Frame Index (i → i+1)")
ax.set_ylabel("RMSD (Å)")
ax.grid(True)

mean_val = kabsch_rmsds.mean()

# === ADD MEAN RMSD TEXT ON PLOT ===
ax.text(
    0.02, 0.95,
    f"Mean RMSD = {mean_val:.3f} Å",
    transform=ax.transAxes,
    fontsize=12,
    verticalalignment='top',
    bbox=dict(facecolor="white", alpha=0.7, edgecolor="black")
)

fig.tight_layout()

# === SAVE PNG ===
out_file = "/content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/METHODS/MethodA/WT/kabsch_rmsd_true_pred_rep1.png"
fig.savefig(out_file, dpi=300, transparent=False)

print(f"📁 Saved RMSD plot to: {out_file}")
print(f"Mean RMSD = {mean_val:.3f} Å")

plt.show()
plt.close(fig)
# Out:
# 100%|██████████| 3999/3999 [00:18<00:00, 215.56it/s]
# 📁 Saved RMSD plot to: /content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/MethodA/WT/kabsch_rmsd_true_pred_rep3.png
# Mean RMSD = 0.867 Å

# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# Store traditional RMSD for both predicted and true trajectories
pred_rmsds = []
true_rmsds = []

model.eval()
with torch.no_grad():
    # First frame as reference
    ref_frame = data_list[0].x[:, :3]

    for i in tqdm(range(len(data_list) - 1)):
        d0 = data_list[i]
        d1 = data_list[i + 1]

        pred = model(d0.x, d0.edge_index, d0.edge_attr)
        true = d1.x[:, :3]

        pred_rmsds.append(compute_kabsch_rmsd(pred, ref_frame))
        true_rmsds.append(compute_kabsch_rmsd(true, ref_frame))

# Convert to numpy
pred_rmsds = np.array(pred_rmsds)
true_rmsds = np.array(true_rmsds)
frame_indices = np.arange(len(pred_rmsds))

mean_true = true_rmsds.mean()
mean_pred = pred_rmsds.mean()

# === FIGURE CREATION (SAFE) ===
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(frame_indices, true_rmsds, label="True Dynamics", marker='o', linewidth=1)
ax.plot(frame_indices, pred_rmsds, label="Predicted Dynamics", marker='x', linewidth=1, linestyle='dashed')

ax.set_title("Traditional RMSD: Predicted vs. True Dynamics")
ax.set_xlabel("Frame Index (relative to first)")
ax.set_ylabel("RMSD (Å)")
ax.grid(True)
ax.legend()

# === ADD MEAN VALUES TEXT TO PLOT ===
text_str = (
    f"Mean True RMSD: {mean_true:.3f} Å\n"
    f"Mean Pred RMSD: {mean_pred:.3f} Å"
)

ax.text(
    0.02, 0.95, text_str,
    transform=ax.transAxes,
    fontsize=12,
    verticalalignment='top',
    bbox=dict(facecolor="white", alpha=0.75, edgecolor="black")
)

fig.tight_layout()

# === SAVE BEFORE SHOW ===
out_file = "/content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/METHODS/MethodA/WT/rmsd_firstframe_true_pred_rep1.png"
fig.savefig(out_file, dpi=300, transparent=False)

print(f"📁 Saved RMSD plot to: {out_file}")

# Show the figure (optional)
plt.show()
plt.close(fig)

# === PRINT STATS IN TERMINAL ===
print(f"✅ Mean True Dynamics RMSD: {mean_true:.3f} Å")
print(f"Min: {true_rmsds.min():.3f} Å | Max: {true_rmsds.max():.3f} Å")

print(f"✅ Mean Predicted Dynamics RMSD: {mean_pred:.3f} Å")
print(f"Min: {pred_rmsds.min():.3f} Å | Max: {pred_rmsds.max():.3f} Å")
# Out:
# 100%|██████████| 3999/3999 [00:21<00:00, 183.15it/s]
# 📁 Saved RMSD plot to: /content/drive/MyDrive/ABE_RF_Diffusion/GNN_AC/HIVPR/MethodA/WT/rmsd_firstframe_true_pred_rep3.png
# ✅ Mean True Dynamics RMSD: 1.215 Å
# Min: 0.696 Å | Max: 1.746 Å
# ✅ Mean Predicted Dynamics RMSD: 1.151 Å
# Min: 0.778 Å | Max: 1.358 Å
